# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# create a set of random longitude and latitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Condition": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asfi
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | broken hill
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | honningsvag
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | ihtiman
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | bantou
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | shimoda
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | lasa
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | jacareacanga
# Processing Record 36 of Set 1 | weligama
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | grand gaube
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | kasane
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | ayagoz
# Processing Record 44 of Set 1 | vila
# Processing Record 45 of Set 1 | sarai
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | bambanglipuro
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | sabang
# Processing Record 50 of Set 1 | hastings
# Processing Record 1 of Set 2 | nome
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | vega de alatorre
# Processing Record 4 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 2 | svetlogorsk
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | wajima
# Processing Record 8 of Set 2 | teguldet
# Processing Record 9 of Set 2 | boda
# Processing Record 10 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | atar
# Processing Record 14 of Set 2 | nandu
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | sakaiminato
# Processing Record 18 of Set 2 | adrar
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | kwinana
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | nouadhibou
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | kapit
# Processing Record 34 of Set 2 | mount isa
# Processing Record 35 of Set 2 | iquitos
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 2 | agadir
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | roma
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | kidal
# Processing Record 46 of Set 2 | cabedelo
# Processing Record 47 of Set 2 | tuatapere
# Processing Record 48 of Set 2 | imbituba
# Processing Record 49 of Set 2 | coquimbo
# Processing Record 50 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | kampong chhnang
# Processing Record 3 of Set 3 | waipawa
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | praia da vitoria
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | lagoa
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | lakes entrance
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | orlik
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | ambunti
# Processing Record 18 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | acarau
# Processing Record 22 of Set 3 | daru
# Processing Record 23 of Set 3 | inhambane
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | antalaha
# Processing Record 28 of Set 3 | bajil
# Processing Record 29 of Set 3 | tezu
# Processing Record 30 of Set 3 | xining
# Processing Record 31 of Set 3 | sur
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | port hawkesbury
# Processing Record 35 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 3 | sambava
# Processing Record 37 of Set 3 | lhokseumawe
# Processing Record 38 of Set 3 | panguna
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | smithers
# Processing Record 41 of Set 3 | asau
# Processing Record 42 of Set 3 | soe
# Processing Record 43 of Set 3 | mehran
# Processing Record 44 of Set 3 | kabalo
# Processing Record 45 of Set 3 | haines junction
# Processing Record 46 of Set 3 | qasigiannguit
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | qujing
# Processing Record 49 of Set 3 | at-bashi
# Processing Record 50 of Set 3 | san quintin
# Processing Record 1 of Set 4 | magadan
# Processing Record 2 of Set 4 | vila velha
# Processing Record 3 of Set 4 | shanghai
# Processing Record 4 of Set 4 | atasu
# Processing Record 5 of Set 4 | icod de los vinos
# Processing Record 6 of Set 4 | irtyshskiy
# Processing Record 7 of Set 4 | constitucion
# Processing Record 8 of Set 4 | camana
# Processing Record 9 of Set 4 | labuhan
# Processing Record 10 of Set 4 | mandalgovi
# Processing Record 11 of Set 4 | deer lake
# Processing Record 12 of Set 4 | avallon
# Processing Record 13 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | saskylakh
# Processing Record 16 of Set 4 | roebourne
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | mehamn
# Processing Record 19 of Set 4 | bengkulu
# Processing Record 20 of Set 4 | mumford
# Processing Record 21 of Set 4 | batan
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | kissamos
# Processing Record 24 of Set 4 | upata
# Processing Record 25 of Set 4 | chicama
# Processing Record 26 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 4 | kushva
# Processing Record 28 of Set 4 | half moon bay
# Processing Record 29 of Set 4 | shingu
# Processing Record 30 of Set 4 | pathein
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | amapa
# Processing Record 33 of Set 4 | saint-jean-de-maurienne
# Processing Record 34 of Set 4 | plover
# Processing Record 35 of Set 4 | krasnosilka
# Processing Record 36 of Set 4 | kashi
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | denpasar
# Processing Record 39 of Set 4 | umm lajj
# Processing Record 40 of Set 4 | plettenberg bay
# Processing Record 41 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 4 | galveston
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | sochi
# Processing Record 46 of Set 4 | atherton
# Processing Record 47 of Set 4 | katangli
# Processing Record 48 of Set 4 | dingle
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | yining
# Processing Record 1 of Set 5 | goure
# Processing Record 2 of Set 5 | ponta delgada
# Processing Record 3 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 4 of Set 5 | nemuro
# Processing Record 5 of Set 5 | caconda
# Processing Record 6 of Set 5 | karasuyama
# Processing Record 7 of Set 5 | xiaoweizhai
# Processing Record 8 of Set 5 | cap malheureux
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | marsa matruh
# Processing Record 11 of Set 5 | saint helens
# Processing Record 12 of Set 5 | korla
# Processing Record 13 of Set 5 | iroquois falls
# Processing Record 14 of Set 5 | dalby
# Processing Record 15 of Set 5 | pangnirtung
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | xingcheng
# Processing Record 19 of Set 5 | guanare
# Processing Record 20 of Set 5 | greymouth
# Processing Record 21 of Set 5 | bilibino
# Processing Record 22 of Set 5 | chapais
# Processing Record 23 of Set 5 | oleksandrivka
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | gushikawa
# Processing Record 26 of Set 5 | bage
# Processing Record 27 of Set 5 | moses lake
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | rio blanco
# Processing Record 30 of Set 5 | ixtapa
# Processing Record 31 of Set 5 | saint-philippe
# Processing Record 32 of Set 5 | riyadh
# Processing Record 33 of Set 5 | novyy urengoy
# Processing Record 34 of Set 5 | businga
# Processing Record 35 of Set 5 | yulara
# Processing Record 36 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 5 | leshan
# Processing Record 38 of Set 5 | beloha
# Processing Record 39 of Set 5 | grindavik
# Processing Record 40 of Set 5 | seymchan
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | jumla
# Processing Record 44 of Set 5 | sanchi
# Processing Record 45 of Set 5 | carnot
# Processing Record 46 of Set 5 | chifeng
# Processing Record 47 of Set 5 | chara
# Processing Record 48 of Set 5 | opuwo
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | gabu
# Processing Record 1 of Set 6 | oxbow
# Processing Record 2 of Set 6 | dhidhdhoo
# Processing Record 3 of Set 6 | harindanga
# Processing Record 4 of Set 6 | kaitangata
# Processing Record 5 of Set 6 | ostrovnoy
# Processing Record 6 of Set 6 | washougal
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | port macquarie
# Processing Record 9 of Set 6 | souillac
# Processing Record 10 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 6 | berdigestyakh
# Processing Record 12 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 13 of Set 6 | hobyo
# Processing Record 14 of Set 6 | longonjo
# Processing Record 15 of Set 6 | anqing
# Processing Record 16 of Set 6 | esperance
# Processing Record 17 of Set 6 | verkhniy avzyan
# Processing Record 18 of Set 6 | nivala
# Processing Record 19 of Set 6 | morgantown
# Processing Record 20 of Set 6 | koyilandi
# City not found. Skipping...
# Processing Record 21 of Set 6 | terra boa
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | kjollefjord
# Processing Record 24 of Set 6 | terney
# Processing Record 25 of Set 6 | dunedin
# Processing Record 26 of Set 6 | chernyshevskiy
# Processing Record 27 of Set 6 | yumen
# Processing Record 28 of Set 6 | bumba
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | pacific grove
# Processing Record 31 of Set 6 | butterworth
# Processing Record 32 of Set 6 | san pedro
# Processing Record 33 of Set 6 | puerto escondido
# Processing Record 34 of Set 6 | airai
# Processing Record 35 of Set 6 | brae
# Processing Record 36 of Set 6 | udachnyy
# Processing Record 37 of Set 6 | mahebourg
# Processing Record 38 of Set 6 | takab
# Processing Record 39 of Set 6 | biak
# Processing Record 40 of Set 6 | mirabad
# Processing Record 41 of Set 6 | klokkarvik
# City not found. Skipping...
# Processing Record 42 of Set 6 | dongsheng
# Processing Record 43 of Set 6 | amarillo
# Processing Record 44 of Set 6 | gusau
# Processing Record 45 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 6 | soyo
# Processing Record 47 of Set 6 | turukhansk
# Processing Record 48 of Set 6 | prince albert
# Processing Record 49 of Set 6 | longyearbyen
# Processing Record 50 of Set 6 | jalu
# Processing Record 1 of Set 7 | rabat
# Processing Record 2 of Set 7 | pevek
# Processing Record 3 of Set 7 | jefferson city
# Processing Record 4 of Set 7 | altay
# Processing Record 5 of Set 7 | moose factory
# Processing Record 6 of Set 7 | mulege
# Processing Record 7 of Set 7 | shenzhen
# Processing Record 8 of Set 7 | waingapu
# Processing Record 9 of Set 7 | meulaboh
# Processing Record 10 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | yellowknife
# Processing Record 13 of Set 7 | shubarshi
# Processing Record 14 of Set 7 | salinopolis
# Processing Record 15 of Set 7 | awjilah
# Processing Record 16 of Set 7 | kosovska mitrovica
# Processing Record 17 of Set 7 | mao
# Processing Record 18 of Set 7 | porto franco
# Processing Record 19 of Set 7 | invermere
# Processing Record 20 of Set 7 | fairlie
# Processing Record 21 of Set 7 | biltine
# Processing Record 22 of Set 7 | diego de almagro
# Processing Record 23 of Set 7 | yeppoon
# Processing Record 24 of Set 7 | berlevag
# Processing Record 25 of Set 7 | aras
# Processing Record 26 of Set 7 | necochea
# Processing Record 27 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | nossa senhora das dores
# Processing Record 29 of Set 7 | payakumbuh
# Processing Record 30 of Set 7 | eydhafushi
# Processing Record 31 of Set 7 | wilkie
# Processing Record 32 of Set 7 | ilulissat
# Processing Record 33 of Set 7 | nuuk
# Processing Record 34 of Set 7 | livingstonia
# Processing Record 35 of Set 7 | nizhniy kuranakh
# Processing Record 36 of Set 7 | rio tercero
# Processing Record 37 of Set 7 | hokitika
# Processing Record 38 of Set 7 | booue
# Processing Record 39 of Set 7 | meadow lake
# Processing Record 40 of Set 7 | kununurra
# Processing Record 41 of Set 7 | capelinha
# Processing Record 42 of Set 7 | champerico
# Processing Record 43 of Set 7 | el zapote
# Processing Record 44 of Set 7 | montclair
# Processing Record 45 of Set 7 | teknaf
# Processing Record 46 of Set 7 | santa vitoria do palmar
# Processing Record 47 of Set 7 | pringsewu
# Processing Record 48 of Set 7 | port augusta
# Processing Record 49 of Set 7 | potosi
# Processing Record 50 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 8 | kemri
# Processing Record 2 of Set 8 | ambilobe
# Processing Record 3 of Set 8 | salalah
# Processing Record 4 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 8 | rocha
# Processing Record 6 of Set 8 | miles city
# Processing Record 7 of Set 8 | mecca
# Processing Record 8 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 9 of Set 8 | verkhniye tatyshly
# Processing Record 10 of Set 8 | kangaatsiaq
# Processing Record 11 of Set 8 | agadez
# Processing Record 12 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 8 | manakara
# Processing Record 14 of Set 8 | atbasar
# Processing Record 15 of Set 8 | hualmay
# Processing Record 16 of Set 8 | evensk
# Processing Record 17 of Set 8 | batagay
# Processing Record 18 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 19 of Set 8 | ola
# Processing Record 20 of Set 8 | roald
# Processing Record 21 of Set 8 | mackay
# Processing Record 22 of Set 8 | ostersund
# Processing Record 23 of Set 8 | inongo
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | alice town
# Processing Record 26 of Set 8 | naryan-mar
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | montepuez
# Processing Record 29 of Set 8 | lavrentiya
# Processing Record 30 of Set 8 | the valley
# Processing Record 31 of Set 8 | tabas
# Processing Record 32 of Set 8 | harper
# Processing Record 33 of Set 8 | limoeiro
# Processing Record 34 of Set 8 | narsaq
# Processing Record 35 of Set 8 | nakhon thai
# Processing Record 36 of Set 8 | kingaroy
# Processing Record 37 of Set 8 | te anau
# Processing Record 38 of Set 8 | dunmore east
# Processing Record 39 of Set 8 | belmonte
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | capitao poco
# Processing Record 42 of Set 8 | ugoofaaru
# Processing Record 43 of Set 8 | hofn
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | dera din panah
# City not found. Skipping...
# Processing Record 46 of Set 8 | krasnorechenskiy
# Processing Record 47 of Set 8 | asilah
# Processing Record 48 of Set 8 | tshane
# Processing Record 49 of Set 8 | kiama
# Processing Record 50 of Set 8 | moskovskiy
# Processing Record 1 of Set 9 | barabai
# Processing Record 2 of Set 9 | belyy yar
# Processing Record 3 of Set 9 | santa isabel
# Processing Record 4 of Set 9 | sao filipe
# Processing Record 5 of Set 9 | lorengau
# Processing Record 6 of Set 9 | yalvac
# Processing Record 7 of Set 9 | masuguru
# Processing Record 8 of Set 9 | altus
# Processing Record 9 of Set 9 | olafsvik
# Processing Record 10 of Set 9 | wuxi
# Processing Record 11 of Set 9 | awbari
# Processing Record 12 of Set 9 | catamarca
# Processing Record 13 of Set 9 | usinsk
# Processing Record 14 of Set 9 | yabelo
# Processing Record 15 of Set 9 | havoysund
# Processing Record 16 of Set 9 | mutoko
# Processing Record 17 of Set 9 | ponta do sol
# Processing Record 18 of Set 9 | vestmanna
# Processing Record 19 of Set 9 | olinda
# Processing Record 20 of Set 9 | geraldton
# Processing Record 21 of Set 9 | ukiah
# Processing Record 22 of Set 9 | liwale
# Processing Record 23 of Set 9 | sola
# Processing Record 24 of Set 9 | linxia
# Processing Record 25 of Set 9 | sumbe
# Processing Record 26 of Set 9 | kushmurun
# Processing Record 27 of Set 9 | skjervoy
# Processing Record 28 of Set 9 | kharan
# Processing Record 29 of Set 9 | cayenne
# Processing Record 30 of Set 9 | nizhnedevitsk
# Processing Record 31 of Set 9 | kutum
# Processing Record 32 of Set 9 | north battleford
# Processing Record 33 of Set 9 | kautokeino
# Processing Record 34 of Set 9 | presidente medici
# Processing Record 35 of Set 9 | buzmeyin
# Processing Record 36 of Set 9 | bonavista
# Processing Record 37 of Set 9 | port moresby
# Processing Record 38 of Set 9 | vallenar
# Processing Record 39 of Set 9 | saluzzo
# Processing Record 40 of Set 9 | mapimi
# Processing Record 41 of Set 9 | hermiston
# Processing Record 42 of Set 9 | methoni
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | itaituba
# Processing Record 45 of Set 9 | murray bridge
# Processing Record 46 of Set 9 | nalut
# Processing Record 47 of Set 9 | dwarahat
# Processing Record 48 of Set 9 | sibolga
# Processing Record 49 of Set 9 | chokurdakh
# Processing Record 50 of Set 9 | maniitsoq
# Processing Record 1 of Set 10 | isangel
# Processing Record 2 of Set 10 | kuytun
# Processing Record 3 of Set 10 | cotonou
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | hutang
# Processing Record 6 of Set 10 | capitan bado
# Processing Record 7 of Set 10 | mayumba
# Processing Record 8 of Set 10 | evreux
# Processing Record 9 of Set 10 | huarmey
# Processing Record 10 of Set 10 | san cristobal
# Processing Record 11 of Set 10 | telimele
# Processing Record 12 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 10 | payo
# Processing Record 14 of Set 10 | batagay-alyta
# Processing Record 15 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 10 | caravelas
# Processing Record 17 of Set 10 | bathsheba
# Processing Record 18 of Set 10 | sabla
# Processing Record 19 of Set 10 | bethel
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | port blair
# Processing Record 22 of Set 10 | saint anthony
# Processing Record 23 of Set 10 | poum
# Processing Record 24 of Set 10 | husavik
# Processing Record 25 of Set 10 | green river
# Processing Record 26 of Set 10 | sao joao da barra
# Processing Record 27 of Set 10 | sovetskiy
# Processing Record 28 of Set 10 | homer
# Processing Record 29 of Set 10 | pemba
# Processing Record 30 of Set 10 | ocampo
# Processing Record 31 of Set 10 | banda aceh
# Processing Record 32 of Set 10 | boa vista
# Processing Record 33 of Set 10 | port keats
# Processing Record 34 of Set 10 | shieli
# Processing Record 35 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 10 | erba
# Processing Record 37 of Set 10 | sabaudia
# Processing Record 38 of Set 10 | kavieng
# Processing Record 39 of Set 10 | viedma
# Processing Record 40 of Set 10 | karlskrona
# Processing Record 41 of Set 10 | pietarsaari
# Processing Record 42 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | kurilsk
# Processing Record 45 of Set 10 | iseyin
# Processing Record 46 of Set 10 | nadym
# Processing Record 47 of Set 10 | tebingtinggi
# Processing Record 48 of Set 10 | oktyabrskoye
# Processing Record 49 of Set 10 | isaccea
# Processing Record 50 of Set 10 | karoi
# Processing Record 1 of Set 11 | khorinsk
# Processing Record 2 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 3 of Set 11 | dubai
# Processing Record 4 of Set 11 | avera
# Processing Record 5 of Set 11 | rio grande
# Processing Record 6 of Set 11 | abatskoye
# Processing Record 7 of Set 11 | velez-malaga
# Processing Record 8 of Set 11 | brus laguna
# Processing Record 9 of Set 11 | kahului
# Processing Record 10 of Set 11 | trogir
# Processing Record 11 of Set 11 | rio gallegos
# Processing Record 12 of Set 11 | maracaibo
# Processing Record 13 of Set 11 | saint-augustin
# Processing Record 14 of Set 11 | stekolnyy
# City not found. Skipping...
# Processing Record 15 of Set 11 | san andres
# Processing Record 16 of Set 11 | hassleholm
# Processing Record 17 of Set 11 | koutsouras
# Processing Record 18 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 19 of Set 11 | chimbote
# Processing Record 20 of Set 11 | yamada
# Processing Record 21 of Set 11 | tirodi
# Processing Record 22 of Set 11 | buraydah
# Processing Record 23 of Set 11 | solnechnyy
# Processing Record 24 of Set 11 | gomfoi
# Processing Record 25 of Set 11 | kalmunai
# Processing Record 26 of Set 11 | fatehpur
# Processing Record 27 of Set 11 | tuensang
# Processing Record 28 of Set 11 | coahuayana
# Processing Record 29 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 11 | nyrob
# Processing Record 31 of Set 11 | henties bay
# Processing Record 32 of Set 11 | camopi
# Processing Record 33 of Set 11 | hamilton
# Processing Record 34 of Set 11 | namatanai
# Processing Record 35 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 11 | kumphawapi
# Processing Record 37 of Set 11 | lano
# Processing Record 38 of Set 11 | dzaoudzi
# Processing Record 39 of Set 11 | barra do garcas
# Processing Record 40 of Set 11 | ceres
# Processing Record 41 of Set 11 | basmat
# Processing Record 42 of Set 11 | filadelfia
# Processing Record 43 of Set 11 | toora-khem
# Processing Record 44 of Set 11 | santiago del estero
# Processing Record 45 of Set 11 | coatlan
# City not found. Skipping...
# Processing Record 46 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | santa cruz
# Processing Record 48 of Set 11 | krasnoselkup
# Processing Record 49 of Set 11 | karratha
# Processing Record 50 of Set 11 | general roca
# Processing Record 1 of Set 12 | ahtopol
# Processing Record 2 of Set 12 | vao
# Processing Record 3 of Set 12 | jinchang
# Processing Record 4 of Set 12 | akyab
# Processing Record 5 of Set 12 | natal
# Processing Record 6 of Set 12 | astana
# Processing Record 7 of Set 12 | acapulco
# Processing Record 8 of Set 12 | vila franca do campo
# Processing Record 9 of Set 12 | christchurch
# Processing Record 10 of Set 12 | richards bay
# Processing Record 11 of Set 12 | warwick
# Processing Record 12 of Set 12 | sobolevo
# Processing Record 13 of Set 12 | yerbogachen
# Processing Record 14 of Set 12 | neuwied
# Processing Record 15 of Set 12 | hambantota
# Processing Record 16 of Set 12 | bireun
# Processing Record 17 of Set 12 | flin flon
# Processing Record 18 of Set 12 | singaraja
# Processing Record 19 of Set 12 | achutupo
# Processing Record 20 of Set 12 | rafraf
# Processing Record 21 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 12 | vitoria
# Processing Record 23 of Set 12 | jacmel
# Processing Record 24 of Set 12 | severka
# Processing Record 25 of Set 12 | maceio
# Processing Record 26 of Set 12 | padang
# Processing Record 27 of Set 12 | vryburg
# Processing Record 28 of Set 12 | terrace
# Processing Record 29 of Set 12 | taltal
# Processing Record 30 of Set 12 | challapata
# Processing Record 31 of Set 12 | bealanana
# Processing Record 32 of Set 12 | tulu bolo
# Processing Record 33 of Set 12 | kavaratti
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | kaili
# Processing Record 36 of Set 12 | whitley bay
# Processing Record 37 of Set 12 | ntoum
# Processing Record 38 of Set 12 | kudahuvadhoo
# Processing Record 39 of Set 12 | vera cruz
# Processing Record 40 of Set 12 | ziyamet
# City not found. Skipping...
# Processing Record 41 of Set 12 | flinders
# Processing Record 42 of Set 12 | urumqi
# Processing Record 43 of Set 12 | fort morgan
# Processing Record 44 of Set 12 | grand-santi
# Processing Record 45 of Set 12 | ust-charyshskaya pristan
# Processing Record 46 of Set 12 | ust-maya
# Processing Record 47 of Set 12 | puerto palomas
# Processing Record 48 of Set 12 | bolitoc
# Processing Record 49 of Set 12 | erzin
# Processing Record 50 of Set 12 | harrismith
# Processing Record 1 of Set 13 | constantine
# Processing Record 2 of Set 13 | ayan
# Processing Record 3 of Set 13 | jamame
# Processing Record 4 of Set 13 | ust-tsilma
# Processing Record 5 of Set 13 | kem
# Processing Record 6 of Set 13 | trairi
# Processing Record 7 of Set 13 | aguimes
# Processing Record 8 of Set 13 | fremont
# Processing Record 9 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 13 | bukachacha
# Processing Record 11 of Set 13 | luganville
# Processing Record 12 of Set 13 | palana
# Processing Record 13 of Set 13 | muroto
# Processing Record 14 of Set 13 | paita
# Processing Record 15 of Set 13 | la libertad
# Processing Record 16 of Set 13 | manggar
# Processing Record 17 of Set 13 | axim
# Processing Record 18 of Set 13 | dauphin
# Processing Record 19 of Set 13 | lalpur
# Processing Record 20 of Set 13 | adamovka
# Processing Record 21 of Set 13 | anito
# Processing Record 22 of Set 13 | mabaruma
# Processing Record 23 of Set 13 | touros
# Processing Record 24 of Set 13 | ternate
# Processing Record 25 of Set 13 | gambettola
# Processing Record 26 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 13 | mayo
# Processing Record 28 of Set 13 | mulchen
# Processing Record 29 of Set 13 | coxim
# Processing Record 30 of Set 13 | taree
# Processing Record 31 of Set 13 | rorvik
# Processing Record 32 of Set 13 | tocopilla
# Processing Record 33 of Set 13 | inta
# Processing Record 34 of Set 13 | contai
# Processing Record 35 of Set 13 | mackenzie
# Processing Record 36 of Set 13 | bubaque
# Processing Record 37 of Set 13 | cleveland
# Processing Record 38 of Set 13 | zvishavane
# Processing Record 39 of Set 13 | palkaka
# City not found. Skipping...
# Processing Record 40 of Set 13 | zverinogolovskoye
# Processing Record 41 of Set 13 | buturlinovka
# Processing Record 42 of Set 13 | ilo
# Processing Record 43 of Set 13 | aswan
# Processing Record 44 of Set 13 | pulandian
# Processing Record 45 of Set 13 | novikovo
# Processing Record 46 of Set 13 | hirara
# Processing Record 47 of Set 13 | abu dhabi
# Processing Record 48 of Set 13 | north platte
# Processing Record 49 of Set 13 | nishihara
# Processing Record 50 of Set 13 | charters towers
# Processing Record 1 of Set 14 | obihiro
# Processing Record 2 of Set 14 | watari
# Processing Record 3 of Set 14 | uyuni
# Processing Record 4 of Set 14 | medicine hat
# Processing Record 5 of Set 14 | alto longa
# Processing Record 6 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 7 of Set 14 | broome
# Processing Record 8 of Set 14 | portland
# Processing Record 9 of Set 14 | cohoes
# Processing Record 10 of Set 14 | nong kung si
# Processing Record 11 of Set 14 | mount barker
# Processing Record 12 of Set 14 | verkh-usugli
# Processing Record 13 of Set 14 | corinto
# Processing Record 14 of Set 14 | garden city
# Processing Record 15 of Set 14 | sencha
# Processing Record 16 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 17 of Set 14 | yenagoa
# Processing Record 18 of Set 14 | jagtial
# Processing Record 19 of Set 14 | mizan teferi
# Processing Record 20 of Set 14 | lunenburg
# Processing Record 21 of Set 14 | margate
# Processing Record 22 of Set 14 | tsuruoka
# Processing Record 23 of Set 14 | noumea
# Processing Record 24 of Set 14 | jardim
# Processing Record 25 of Set 14 | bafq
# Processing Record 26 of Set 14 | twentynine palms
# Processing Record 27 of Set 14 | santa catarina de tepehuanes
# Processing Record 28 of Set 14 | altamira
# Processing Record 29 of Set 14 | kiyasovo
# Processing Record 30 of Set 14 | alta floresta
# Processing Record 31 of Set 14 | boditi
# Processing Record 32 of Set 14 | aktash
# Processing Record 33 of Set 14 | nuevo progreso
# Processing Record 34 of Set 14 | mamburao
# Processing Record 35 of Set 14 | yamoussoukro
# Processing Record 36 of Set 14 | kibakwe
# Processing Record 37 of Set 14 | saint-francois
# Processing Record 38 of Set 14 | ingham
# Processing Record 39 of Set 14 | urusha
# Processing Record 40 of Set 14 | castra-nova
# Processing Record 41 of Set 14 | muncar
# Processing Record 42 of Set 14 | pudozh
# Processing Record 43 of Set 14 | taunggyi
# Processing Record 44 of Set 14 | pantayivka
# Processing Record 45 of Set 14 | makarska
# Processing Record 46 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 14 | muzhappilangad
# City not found. Skipping...
# Processing Record 48 of Set 14 | alice springs
# Processing Record 49 of Set 14 | nushki
# Processing Record 50 of Set 14 | ulaangom
# Processing Record 1 of Set 15 | grand-lahou
# Processing Record 2 of Set 15 | severnyy
# Processing Record 3 of Set 15 | cantaura
# Processing Record 4 of Set 15 | tiznit
# Processing Record 5 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 15 | los llanos de aridane
# Processing Record 7 of Set 15 | bahia honda
# Processing Record 8 of Set 15 | verkhnevilyuysk
# Processing Record 9 of Set 15 | balykshi
# Processing Record 10 of Set 15 | sturgeon bay
# Processing Record 11 of Set 15 | nador
# Processing Record 12 of Set 15 | naile
# City not found. Skipping...
# Processing Record 13 of Set 15 | tarakan
# Processing Record 14 of Set 15 | shuyskoye
# Processing Record 15 of Set 15 | buala
# Processing Record 16 of Set 15 | camacha
# Processing Record 17 of Set 15 | kunzelsau
# Processing Record 18 of Set 15 | carutapera
# Processing Record 19 of Set 15 | kuruman
# Processing Record 20 of Set 15 | zhangye
# Processing Record 21 of Set 15 | mocuba
# Processing Record 22 of Set 15 | parrita
# Processing Record 23 of Set 15 | gornopravdinsk
# Processing Record 24 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 25 of Set 15 | nyzhni sirohozy
# Processing Record 26 of Set 15 | inirida
# Processing Record 27 of Set 15 | juneau
# Processing Record 28 of Set 15 | banhigan
# Processing Record 29 of Set 15 | ranau
# Processing Record 30 of Set 15 | luwuk
# Processing Record 31 of Set 15 | wewak
# Processing Record 32 of Set 15 | volokolamsk
# Processing Record 33 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 15 | takoradi
# Processing Record 35 of Set 15 | sulangan
# Processing Record 36 of Set 15 | itoman
# Processing Record 37 of Set 15 | pompeia
# Processing Record 38 of Set 15 | pital
# Processing Record 39 of Set 15 | palasa
# Processing Record 40 of Set 15 | celestun
# Processing Record 41 of Set 15 | yarada
# Processing Record 42 of Set 15 | velsk
# Processing Record 43 of Set 15 | tual
# Processing Record 44 of Set 15 | thinadhoo
# Processing Record 45 of Set 15 | saint andrews
# Processing Record 46 of Set 15 | lerwick
# Processing Record 47 of Set 15 | luau
# Processing Record 48 of Set 15 | bur gabo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng Current Condition  Max Temp  Humidity  \
# 0         Asfi  32.2994   -9.2372        light rain     54.84        69
# 1  Tuktoyaktuk  69.4541 -133.0374         clear sky     -5.80        77
# 2        Tiksi  71.6872  128.8694   overcast clouds    -22.43        87
# 3       Hasaki  35.7333  140.8333        few clouds     46.00        28
# 4  Broken Hill -31.9500  141.4333         clear sky     91.40        17
# 5     Luderitz -26.6481   15.1594        few clouds     69.82        49
# 6     Cherskiy  68.7500  161.3000   overcast clouds    -26.01        85
# 7       Albany  42.6001  -73.9662     broken clouds     25.00        58
# 8        Kapaa  22.0752 -159.3190   overcast clouds     73.40        88
# 9      Iqaluit  63.7506  -68.5145        light snow     12.20        79
#
#    Cloudiness  Wind Speed Country
# 0          98       21.30      MA
# 1           1       11.50      CA
# 2         100        6.04      RU
# 3          20        6.91      JP
# 4           0       12.66      AU
# 5          11       17.83      NA
# 6          99        4.65      RU
# 7          66        1.01      US
# 8          90        9.22      US
# 9          75        3.44      CA

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Condition"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Asfi      MA  32.2994   -9.2372     54.84        69          98
# 1  Tuktoyaktuk      CA  69.4541 -133.0374     -5.80        77           1
# 2        Tiksi      RU  71.6872  128.8694    -22.43        87         100
# 3       Hasaki      JP  35.7333  140.8333     46.00        28          20
# 4  Broken Hill      AU -31.9500  141.4333     91.40        17           0
# 5     Luderitz      NA -26.6481   15.1594     69.82        49          11
# 6     Cherskiy      RU  68.7500  161.3000    -26.01        85          99
# 7       Albany      US  42.6001  -73.9662     25.00        58          66
# 8        Kapaa      US  22.0752 -159.3190     73.40        88          90
# 9      Iqaluit      CA  63.7506  -68.5145     12.20        79          75
#
#    Wind Speed Current Condition
# 0       21.30        light rain
# 1       11.50         clear sky
# 2        6.04   overcast clouds
# 3        6.91        few clouds
# 4       12.66         clear sky
# 5       17.83        few clouds
# 6        4.65   overcast clouds
# 7        1.01     broken clouds
# 8        9.22   overcast clouds
# 9        3.44        light snow

# %%
# Creat the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
